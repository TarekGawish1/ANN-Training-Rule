# %%
x1 = [1, 1, -1, -1]
x2 = [1, -1, 1, -1]
bIn = [1, 1, 1, 1]
y = [1, -1, -1, -1]

w1 = 0
w2 = 0
b = 0

# %%
for j in range(len(x1)):
    w1 = w1 + x1[j] * y[j]
    w2 = w2 + x2[j] * y[j]
    b = b + y[j]
    print(f"w1(new): {w1}\tw2(new): {w2}\tb(new): {b}")

print("final weghts: ",w1,w2,b)
# Out:
# w1(new): 1	w2(new): 1	b(new): 1
# w1(new): 0	w2(new): 2	b(new): 0
# w1(new): 1	w2(new): 1	b(new): -1
# w1(new): 2	w2(new): 2	b(new): -2
# final weghts:  2 2 -2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("testing the network: ") 
for j in range(len(x1)):
    y = x1[j] * w1 + x2[j] * w2 + bIn[j] *b 
    print("y= ",y)

print(f"Decision Boundary: {w1}x1 + {w2}x2 + ({b})b = 0")
# Out:
# testing the network:
# y=  2
# y=  -2
# y=  -2
# y=  -6
# Decision Boundary: 2x1 + 2x2 + (-2)b = 0

# %% [markdown]
# ![image.png](attachment:image.png)
